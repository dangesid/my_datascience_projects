# %%
import pandas as pd

# %%
df = pd.read_csv(r"car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
# Unique values in categorical features are: 

print(df["Seller_Type"].unique())
print(df["Transmission"].unique())
print(df["Owner"].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
# Check missing or null values 

df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# Feature engineering ---> Add the column with new feature : How much old is the car 

df = df.drop("Car_Name",axis=1)

# %% [raw]
# # Feature engineering ---> Add the column with new feature : How much old is the car

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
df["Current_Year"]=2024

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2024
# 1       Manual      0          2024
# 2       Manual      0          2024
# 3       Manual      0          2024
# 4       Manual      0          2024

# %%
df["No_Year"] = df["Current_Year"]-df["Year"]

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  No_Year
# 0       Manual      0          2024       10
# 1       Manual      0          2024       11
# 2       Manual      0          2024        7
# 3       Manual      0          2024       13
# 4       Manual      0          2024       10

# %%
df = df.drop(["Year","Current_Year"],axis=1)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  No_Year
# 0       Manual      0       10
# 1       Manual      0       11
# 2       Manual      0        7
# 3       Manual      0       13
# 4       Manual      0       10

# %%
# One Hot Encoding 

df = pd.get_dummies(df,drop_first=True).astype(int)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  No_Year  Fuel_Type_Diesel  \
# 0              3              5       27000      0       10                 0
# 1              4              9       43000      0       11                 1
# 2              7              9        6900      0        7                 0
# 3              2              4        5200      0       13                 0
# 4              4              6       42450      0       10                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
df.corr()  # How one feature is correlated with others
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.877518    0.032597 -0.083877
# Present_Price                0.877518       1.000000    0.206896  0.007089
# Kms_Driven                   0.032597       0.206896    1.000000  0.089216
# Owner                       -0.083877       0.007089    0.089216  1.000000
# No_Year                     -0.229302       0.049269    0.524342  0.182104
# Fuel_Type_Diesel             0.547371       0.472090    0.172515 -0.053469
# Fuel_Type_Petrol            -0.535179      -0.464390   -0.172874  0.055687
# Seller_Type_Individual      -0.542332      -0.515092   -0.101419  0.124269
# Transmission_Manual         -0.367935      -0.349275   -0.162510 -0.050316
#
#                          No_Year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.229302          0.547371         -0.535179
# Present_Price           0.049269          0.472090         -0.464390
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(df)

# %%
corrmat=df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heatmap
g = sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  No_Year  Fuel_Type_Diesel  \
# 0              3              5       27000      0       10                 0
# 1              4              9       43000      0       11                 1
# 2              7              9        6900      0        7                 0
# 3              2              4        5200      0       13                 0
# 4              4              6       42450      0       10                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
X = df.iloc[:,1:]
y = df.iloc[:,0]

# print(X) # Independent 
# print(y) # Dependent

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  No_Year  Fuel_Type_Diesel  \
# 0              5       27000      0       10                 0
# 1              9       43000      0       11                 1
# 2              9        6900      0        7                 0
# 3              4        5200      0       13                 0
# 4              6       42450      0       10                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
y.head()
# Out:
# 0    3
# 1    4
# 2    7
# 3    2
# 4    4
# Name: Selling_Price, dtype: int64

# %%
# Feature Importance 

from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.40367353 0.0467409  0.00175009 0.07933443 0.21348546 0.01335763
#  0.1222515  0.11940646]

# %%
# Plot graph of feature Importance 

feature_importance = pd.Series(model.feature_importances_,index=X.columns)
feature_importance.nlargest(5).plot(kind="barh")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test ,y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (240, 8)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_random = RandomForestRegressor()

# %%
### HyperParameters 
import numpy as np 


n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)

max_features = ['log2','sqrt']

max_depth = [int(x) for x in np.linspace(5,30,num=6)]

min_sample_split = [2,5,10,15,100]

min_sample_leaf = [1,2,5,10]
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV  # this will help us to find the best parameters from the above that we defined

# create a random grid

random_grid = { 'n_estimators': n_estimators,
                'max_features': max_features,
                'max_depth' : max_depth,
                'min_samples_split': min_sample_split,
                'min_samples_leaf': min_sample_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['log2', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator= rf, param_distributions= random_grid,scoring='neg_mean_squared_error',n_iter=10,cv=5,verbose=2,random_state=42,n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   0.4s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   0.4s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   0.4s
# ...

# %%
predictions = rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 6.9998,  3.805 ,  2.194 ,  2.524 ,  8.308 , 23.8458,  0.083 ,
#         4.928 ,  4.624 ,  7.343 ,  0.751 ,  2.116 ,  5.097 ,  3.122 ,
#         3.093 , 20.613 , 10.787 ,  4.855 ,  0.048 ,  4.218 ,  5.593 ,
#        10.162 ,  4.89  ,  0.926 ,  0.126 ,  8.3958,  2.061 ,  0.911 ,
#        22.636 ,  0.105 ,  0.069 ,  0.653 ,  4.689 ,  5.748 ,  4.947 ,
#         5.593 ,  6.263 ,  6.1158,  5.195 ,  4.72  ,  9.6778,  6.236 ,
#         7.5868,  3.249 ,  6.403 ,  6.125 ,  2.639 ,  7.3738,  5.365 ,
#         0.272 ,  0.024 ,  3.832 ,  6.449 , 21.279 ,  1.991 ,  4.122 ,
#         8.771 ,  0.522 ,  5.065 ,  3.8   ,  2.017 ])

# %%
sns.displot(y_test - predictions)

# %%
plt.scatter(y_test,predictions)

# %%
import pickle 

file = open('rf_carDekho_regression_model.pkl','wb')

pickle.dump(rf_random,file)
